# %%
import torch
from torch import nn
import matplotlib.pyplot as plt
import numpy as np
start=0
end=10
step_size=0.3
X=torch.arange(start,end,step_size).unsqueeze(dim=1)
weight=0.35
bias=torch.randn_like(X)*0.1
y=weight*X+bias
train_split=int(len(X)*0.8)

# %%
X_train,y_train=X[:train_split],y[:train_split]
X_test,y_test=X[train_split:],y[train_split:]
X_train,y_train
# Out:
# (tensor([[0.0000],
#          [0.3000],
#          [0.6000],
#          [0.9000],
#          [1.2000],
#          [1.5000],
#          [1.8000],
#          [2.1000],
#          [2.4000],
#          [2.7000],
#          [3.0000],
#          [3.3000],
#          [3.6000],
#          [3.9000],
#          [4.2000],
#          [4.5000],
#          [4.8000],
#          [5.1000],
#          [5.4000],
#          [5.7000],
#          [6.0000],
#          [6.3000],
#          [6.6000],
#          [6.9000],
#          [7.2000],
#          [7.5000],
#          [7.8000]]),
#  tensor([[0.1927],
#          [0.2537],
#          [0.3001],
#          [0.1044],
#          [0.4878],
#          [0.4015],
#          [0.6257],
#          [0.5745],
#          [0.7648],
#          [1.1099],
#          [1.0108],
#          [1.0146],
#          [1.1872],
#          [1.3091],
#          [1.3931],
#          [1.6512],
#          [1.8442],
#          [1.7690],
#          [1.8677],
#          [2.1667],
#          [2.1319],
#          [2.1625],
#          [2.3406],
#          [2.3375],
#          [2.5235],
#          [2.6571],
#          [2.6420]]))

# %%
class LinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        # self.weight=nn.Parameter(torch.randn(1,requires_grad=True,dtype=torch.float32))
        # self.bias=nn.Parameter(torch.randn(1,requires_grad=True,dtype=torch.float32))
        self.linear_layer=nn.Linear(in_features=1,out_features=1)
    def forward(self,x:torch.tensor):
        # return self.weight*x+self.bias
        return self.linear_layer(x)

# %%
model=LinearRegressionModel()
torch.manual_seed(42)
list(model.parameters())
# Out:
# [Parameter containing:
#  tensor([[-0.9899]], requires_grad=True),
#  Parameter containing:
#  tensor([-0.3864], requires_grad=True)]

# %%
def plots(train_data=X_train,train_label=y_train,
          test_data=X_test,test_label=y_test,
          predictions=None):
    plt.figure(figsize=(10,7))
    plt.scatter(train_data,train_label,c="b")
    plt.scatter(test_data,test_label,c="r")

    if predictions is not None:
        plt.scatter(test_data,predictions,c="g")

# %%
plots()

# %%
with torch.inference_mode():
    y_preds=model(X_test)
plots(predictions=y_preds)

# %%
loss_fn=nn.L1Loss()
loss_fn
# Out:
# L1Loss()

# %%
optimizer=torch.optim.SGD(params=model.parameters(),lr=0.1)

# %%
epochs=200
train_loss_values = []
test_loss_values = []
epoch_count = []
for epoch in range(epochs):
    model.train()
    y_pred_train=model(X_train)
    loss=loss_fn(y_pred_train,y_train)
    optimizer.zero_grad()
    loss.backward()
    # print(f"loss before optimizer step {loss}")
    optimizer.step()

    #for test loss loop
    model.eval()
    with torch.no_grad():
         y_pred_test=model(X_test)
         loss_test=loss_fn(y_pred_test,y_test)
         # print(f"loss after optimizer step {loss_test}")
    print(model.state_dict())
    if epoch%10==0:
        epoch_count.append(epoch)
        train_loss_values.append(loss.detach().numpy())
        test_loss_values.append(loss_test.detach().numpy())
        print(f"loss before optimizer step {loss}")
        print(f"loss after optimizer step {loss_test}")
        print(epoch)
# Out:
# OrderedDict([('linear_layer.weight', tensor([[-0.5999]])), ('linear_layer.bias', tensor([-0.2864]))])
# loss before optimizer step 5.61085844039917
# loss after optimizer step 8.80700969696045
# 0
# OrderedDict([('linear_layer.weight', tensor([[-0.2099]])), ('linear_layer.bias', tensor([-0.1864]))])
# OrderedDict([('linear_layer.weight', tensor([[0.1801]])), ('linear_layer.bias', tensor([-0.0864]))])
# OrderedDict([('linear_layer.weight', tensor([[0.5701]])), ('linear_layer.bias', tensor([0.0136]))])
# OrderedDict([('linear_layer.weight', tensor([[0.1823]])), ('linear_layer.bias', tensor([-0.0715]))])
# OrderedDict([('linear_layer.weight', tensor([[0.5723]])), ('linear_layer.bias', tensor([0.0285]))])
# OrderedDict([('linear_layer.weight', tensor([[0.1845]])), ('linear_layer.bias', tensor([-0.0567]))])
# OrderedDict([('linear_layer.weight', tensor([[0.5679]])), ('linear_layer.bias', tensor([0.0359]))])
# OrderedDict([('linear_layer.weight', tensor([[0.1801]])), ('linear_layer.bias', tensor([-0.0493]))])
# OrderedDict([('linear_layer.weight', tensor([[0.5634]])), ('linear_layer.bias', tensor([0.0433]))])
# OrderedDict([('linear_layer.weight', tensor([[0.1756]])), ('linear_layer.bias', tensor([-0.0419]))])
# loss before optimizer step 0.8909092545509338
# loss after optimizer step 1.5825642347335815
# 10
# OrderedDict([('linear_layer.weight', tensor([[0.5590]])), ('linear_layer.bias', tensor([0.0507]))])
# OrderedDict([('linear_layer.weight', tensor([[0.1712]])), ('linear_layer.bias', tensor([-0.0345]))])
# OrderedDict([('linear_layer.weight', tensor([[0.5545]])), ('linear_layer.bias', tensor([0.0581]))])
# OrderedDict([('linear_layer.weight', tensor([[0.1668]])), ('linear_layer.bias', tensor([-0.0271]))])
# OrderedDict([('linear_layer.weight', tensor([[0.5501]])), ('linear_layer.bias', tensor([0.0655]))])
# OrderedDict([('linear_layer.weight', tensor([[0.1623]])), ('linear_layer.bias', tensor([-0.0197]))])
# OrderedDict([('linear_layer.weight', tensor([[0.5456]])), ('linear_layer.bias', tensor([0.0729]))])
# OrderedDict([('linear_layer.weight', tensor([[0.1579]])), ('linear_layer.bias', tensor([-0.0123]))])
# OrderedDict([('linear_layer.weight', tensor([[0.5412]])), ('linear_layer.bias', tensor([0.0803]))])
# OrderedDict([('linear_layer.weight', tensor([[0.1534]])), ('linear_layer.bias', tensor([-0.0049]))])
# loss before optimizer step 0.8362869024276733
# loss after optimizer step 1.7455261945724487
# 20
# OrderedDict([('linear_layer.weight', tensor([[0.5368]])), ('linear_layer.bias', tensor([0.0877]))])
# OrderedDict([('linear_layer.weight', tensor([[0.1490]])), ('linear_layer.bias', tensor([0.0025]))])
# OrderedDict([('linear_layer.weight', tensor([[0.5323]])), ('linear_layer.bias', tensor([0.0951]))])
# OrderedDict([('linear_layer.weight', tensor([[0.1423]])), ('linear_layer.bias', tensor([0.0025]))])
# OrderedDict([('linear_layer.weight', tensor([[0.5256]])), ('linear_layer.bias', tensor([0.0951]))])
# OrderedDict([('linear_layer.weight', tensor([[0.1379]])), ('linear_layer.bias', tensor([0.0099]))])
# OrderedDict([('linear_layer.weight', tensor([[0.5212]])), ('linear_layer.bias', tensor([0.1025]))])
# OrderedDict([('linear_layer.weight', tensor([[0.1312]])), ('linear_layer.bias', tensor([0.0099]))])
# OrderedDict([('linear_layer.weight', tensor([[0.5145]])), ('linear_layer.bias', tensor([0.1025]))])
# OrderedDict([('linear_layer.weight', tensor([[0.1245]])), ('linear_layer.bias', tensor([0.0099]))])
# loss before optimizer step 0.7520439624786377
# loss after optimizer step 1.9907108545303345
# 30
# OrderedDict([('linear_layer.weight', tensor([[0.5079]])), ('linear_layer.bias', tensor([0.1025]))])
# OrderedDict([('linear_layer.weight', tensor([[0.1179]])), ('linear_layer.bias', tensor([0.0099]))])
# OrderedDict([('linear_layer.weight', tensor([[0.5012]])), ('linear_layer.bias', tensor([0.1025]))])
# OrderedDict([('linear_layer.weight', tensor([[0.1134]])), ('linear_layer.bias', tensor([0.0173]))])
# OrderedDict([('linear_layer.weight', tensor([[0.4968]])), ('linear_layer.bias', tensor([0.1099]))])
# OrderedDict([('linear_layer.weight', tensor([[0.1068]])), ('linear_layer.bias', tensor([0.0173]))])
# OrderedDict([('linear_layer.weight', tensor([[0.4901]])), ('linear_layer.bias', tensor([0.1099]))])
# OrderedDict([('linear_layer.weight', tensor([[0.1001]])), ('linear_layer.bias', tensor([0.0173]))])
# OrderedDict([('linear_layer.weight', tensor([[0.4834]])), ('linear_layer.bias', tensor([0.1099]))])
# OrderedDict([('linear_layer.weight', tensor([[0.0934]])), ('linear_layer.bias', tensor([0.0173]))])
# loss before optimizer step 0.6375697255134583
# loss after optimizer step 2.2633025646209717
# 40
# OrderedDict([('linear_layer.weight', tensor([[0.4834]])), ('linear_layer.bias', tensor([0.1173]))])
# OrderedDict([('linear_layer.weight', tensor([[0.0934]])), ('linear_layer.bias', tensor([0.0248]))])
# OrderedDict([('linear_layer.weight', tensor([[0.4768]])), ('linear_layer.bias', tensor([0.1173]))])
# OrderedDict([('linear_layer.weight', tensor([[0.0868]])), ('linear_layer.bias', tensor([0.0248]))])
# OrderedDict([('linear_layer.weight', tensor([[0.4768]])), ('linear_layer.bias', tensor([0.1248]))])
# OrderedDict([('linear_layer.weight', tensor([[0.0868]])), ('linear_layer.bias', tensor([0.0322]))])
# OrderedDict([('linear_layer.weight', tensor([[0.4701]])), ('linear_layer.bias', tensor([0.1248]))])
# OrderedDict([('linear_layer.weight', tensor([[0.0801]])), ('linear_layer.bias', tensor([0.0322]))])
# OrderedDict([('linear_layer.weight', tensor([[0.4701]])), ('linear_layer.bias', tensor([0.1322]))])
# OrderedDict([('linear_layer.weight', tensor([[0.0801]])), ('linear_layer.bias', tensor([0.0396]))])
# loss before optimizer step 0.6061458587646484
# loss after optimizer step 2.3610806465148926
# 50
# OrderedDict([('linear_layer.weight', tensor([[0.4634]])), ('linear_layer.bias', tensor([0.1322]))])
# OrderedDict([('linear_layer.weight', tensor([[0.0734]])), ('linear_layer.bias', tensor([0.0396]))])
# OrderedDict([('linear_layer.weight', tensor([[0.4568]])), ('linear_layer.bias', tensor([0.1322]))])
# OrderedDict([('linear_layer.weight', tensor([[0.0668]])), ('linear_layer.bias', tensor([0.0396]))])
# OrderedDict([('linear_layer.weight', tensor([[0.4568]])), ('linear_layer.bias', tensor([0.1396]))])
# OrderedDict([('linear_layer.weight', tensor([[0.0668]])), ('linear_layer.bias', tensor([0.0470]))])
# OrderedDict([('linear_layer.weight', tensor([[0.4501]])), ('linear_layer.bias', tensor([0.1396]))])
# OrderedDict([('linear_layer.weight', tensor([[0.0601]])), ('linear_layer.bias', tensor([0.0470]))])
# OrderedDict([('linear_layer.weight', tensor([[0.4501]])), ('linear_layer.bias', tensor([0.1470]))])
# OrderedDict([('linear_layer.weight', tensor([[0.0601]])), ('linear_layer.bias', tensor([0.0544]))])
# loss before optimizer step 0.5418633818626404
# loss after optimizer step 2.526265859603882
# 60
# OrderedDict([('linear_layer.weight', tensor([[0.4434]])), ('linear_layer.bias', tensor([0.1470]))])
# OrderedDict([('linear_layer.weight', tensor([[0.0534]])), ('linear_layer.bias', tensor([0.0544]))])
# OrderedDict([('linear_layer.weight', tensor([[0.4434]])), ('linear_layer.bias', tensor([0.1544]))])
# OrderedDict([('linear_layer.weight', tensor([[0.0534]])), ('linear_layer.bias', tensor([0.0618]))])
# OrderedDict([('linear_layer.weight', tensor([[0.4368]])), ('linear_layer.bias', tensor([0.1544]))])
# OrderedDict([('linear_layer.weight', tensor([[0.0468]])), ('linear_layer.bias', tensor([0.0618]))])
# OrderedDict([('linear_layer.weight', tensor([[0.4368]])), ('linear_layer.bias', tensor([0.1618]))])
# OrderedDict([('linear_layer.weight', tensor([[0.0468]])), ('linear_layer.bias', tensor([0.0692]))])
# OrderedDict([('linear_layer.weight', tensor([[0.4301]])), ('linear_layer.bias', tensor([0.1618]))])
# OrderedDict([('linear_layer.weight', tensor([[0.0401]])), ('linear_layer.bias', tensor([0.0692]))])
# loss before optimizer step 0.4775807857513428
# loss after optimizer step 2.691450595855713
# 70
# OrderedDict([('linear_layer.weight', tensor([[0.4234]])), ('linear_layer.bias', tensor([0.1618]))])
# OrderedDict([('linear_layer.weight', tensor([[0.0334]])), ('linear_layer.bias', tensor([0.0692]))])
# OrderedDict([('linear_layer.weight', tensor([[0.4234]])), ('linear_layer.bias', tensor([0.1692]))])
# OrderedDict([('linear_layer.weight', tensor([[0.0334]])), ('linear_layer.bias', tensor([0.0766]))])
# OrderedDict([('linear_layer.weight', tensor([[0.4168]])), ('linear_layer.bias', tensor([0.1692]))])
# OrderedDict([('linear_layer.weight', tensor([[0.0268]])), ('linear_layer.bias', tensor([0.0766]))])
# OrderedDict([('linear_layer.weight', tensor([[0.4168]])), ('linear_layer.bias', tensor([0.1766]))])
# OrderedDict([('linear_layer.weight', tensor([[0.0268]])), ('linear_layer.bias', tensor([0.0840]))])
# OrderedDict([('linear_layer.weight', tensor([[0.4101]])), ('linear_layer.bias', tensor([0.1766]))])
# OrderedDict([('linear_layer.weight', tensor([[0.0201]])), ('linear_layer.bias', tensor([0.0840]))])
# loss before optimizer step 0.4132983684539795
# loss after optimizer step 2.856635570526123
# 80
# OrderedDict([('linear_layer.weight', tensor([[0.4101]])), ('linear_layer.bias', tensor([0.1840]))])
# OrderedDict([('linear_layer.weight', tensor([[0.0201]])), ('linear_layer.bias', tensor([0.0914]))])
# OrderedDict([('linear_layer.weight', tensor([[0.4034]])), ('linear_layer.bias', tensor([0.1840]))])
# OrderedDict([('linear_layer.weight', tensor([[0.0134]])), ('linear_layer.bias', tensor([0.0914]))])
# OrderedDict([('linear_layer.weight', tensor([[0.4034]])), ('linear_layer.bias', tensor([0.1914]))])
# OrderedDict([('linear_layer.weight', tensor([[0.0134]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3968]])), ('linear_layer.bias', tensor([0.1914]))])
# OrderedDict([('linear_layer.weight', tensor([[0.0068]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1914]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# loss before optimizer step 0.34901583194732666
# loss after optimizer step 3.021820545196533
# 90
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# loss before optimizer step 0.3563288450241089
# loss after optimizer step 3.021820545196533
# 100
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# loss before optimizer step 0.3563288450241089
# loss after optimizer step 3.021820545196533
# 110
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# loss before optimizer step 0.3563288450241089
# loss after optimizer step 3.021820545196533
# 120
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# loss before optimizer step 0.3563288450241089
# loss after optimizer step 3.021820545196533
# 130
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# loss before optimizer step 0.3563288450241089
# loss after optimizer step 3.021820545196533
# 140
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# loss before optimizer step 0.3563288450241089
# loss after optimizer step 3.021820545196533
# 150
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# loss before optimizer step 0.3563288450241089
# loss after optimizer step 3.021820545196533
# 160
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# loss before optimizer step 0.3563288450241089
# loss after optimizer step 3.021820545196533
# 170
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# loss before optimizer step 0.3563288450241089
# loss after optimizer step 3.021820545196533
# 180
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# loss before optimizer step 0.3563288450241089
# loss after optimizer step 3.021820545196533
# 190
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])
# OrderedDict([('linear_layer.weight', tensor([[9.2000e-05]])), ('linear_layer.bias', tensor([0.0988]))])
# OrderedDict([('linear_layer.weight', tensor([[0.3901]])), ('linear_layer.bias', tensor([0.1988]))])

# %%
with torch.inference_mode():
    y_pred_la=model(X_test)
plots(predictions=y_pred_la)

# %%
import matplotlib.pyplot as plt

plt.plot(epoch_count, train_loss_values, label="Train Loss")
plt.plot(epoch_count, test_loss_values, label="Test Loss")
plt.legend()
plt.show()
