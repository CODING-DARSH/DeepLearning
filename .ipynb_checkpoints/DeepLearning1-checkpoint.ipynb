# %%
import torch 
from torch import nn
import matplotlib.pyplot as plt
torch.__version__
# Out:
# '2.10.0+cpu'

# %%
weight=0.5
bias=0.2
start=0
end=1
step=0.02
X=torch.arange(start,end,step).unsqueeze(dim=1)
y=weight*X +bias
train_split=int(0.8*len(X))
# train_split
X

# %%
X_train,y_train=X[:train_split],y[:train_split]
X_test,y_test=X[train_split:],y[train_split:]

# %%
len(X_train),len(y_train),len(y_test)
# Out:
# (40, 40, 10)

# %%
"""
Plotting a graph for visualization
"""
def plot_pred(train_data=X_train,
             train_label=y_train,
             test_data=X_test,
             test_label=y_test,
             predictions=None):
    plt.figure(figsize=(10,7))
    plt.scatter(train_data,train_label,c="b")
    plt.scatter(test_data,test_label,c="g")
    if predictions is not None:
        plt.scatter(test_data,predictions,c="r")
    plt.legend(prop={"size": 14});

# %%
plot_pred()
# Out:
# C:\Users\Darsh\AppData\Local\Temp\ipykernel_24896\2038289084.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(prop={"size": 14});

# %%
#Building basic linear regression model in pytorch 

class LinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.weights=nn.Parameter(torch.randn(1,requires_grad=True,dtype=torch.float32))
        self.bias=nn.Parameter(torch.randn(1,requires_grad=True,dtype=torch.float32))
    def forward(self,x:torch.tensor)->torch.Tensor:
        return self.weights*x+self.bias

# %%
torch.manual_seed(42) # with random seed we can ensure that every time random initiate of weight,size parameter stays constant
model_0=LinearRegressionModel()
list(model_0.parameters())
# Out:
# [Parameter containing:
#  tensor([0.3367], requires_grad=True),
#  Parameter containing:
#  tensor([0.1288], requires_grad=True)]

# %%
with torch.inference_mode():  #when we just wanna check prediction and we dont want gradient descent and back prop we use this
    y_preds=model_0(X_test)
y_preds
# Out:
# tensor([[0.3982],
#         [0.4049],
#         [0.4116],
#         [0.4184],
#         [0.4251],
#         [0.4318],
#         [0.4386],
#         [0.4453],
#         [0.4520],
#         [0.4588]])

# %%
plot_pred(predictions=y_preds)
# Out:
# C:\Users\Darsh\AppData\Local\Temp\ipykernel_24896\2038289084.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(prop={"size": 14});

# %%
loss_fn=nn.L1Loss()
#loss function measures loss between predicted and actuall value

# %%
loss_fn
# Out:
# L1Loss()

# %%
optimizer=torch.optim.SGD(params=model_0.parameters(),lr=0.01)
#optimizer try to modify parameters such as weight and bias to reduce the loss we hve SGD is stochastic gradient descent is
#optimizer/works like gradient descent it try to reduce the loss by balancing weight and 
#lr is how drastically we wanna change our parameters and its also comes under hyperperameter

# %%
torch.manual_seed(42)
epochs=50
for epoch in range(epochs):
    model_0.train()

    y_pred=model_0(X_train)
    
    loss=loss_fn(y_pred,y_train)
    
    optimizer.zero_grad()

    loss.backward()

    optimizer.step() # it updates parameters and trys to move it forward or near to our answer 
    with torch.no_grad():
        test_pred=model_0(X_test)
        test_loss=loss_fn(test_pred,y_test)
    if epoch%10==0:
        print(f"Epoch: {epoch} | Loss : {loss}| test loss:{test_loss}")
        print(model_0.state_dict())
# Out:
# Epoch: 0 | Loss : 0.004575380124151707| test loss:0.004555904772132635
# OrderedDict([('weights', tensor([0.4952])), ('bias', tensor([0.2088]))])
# Epoch: 10 | Loss : 0.004575380124151707| test loss:0.004555904772132635
# OrderedDict([('weights', tensor([0.4952])), ('bias', tensor([0.2088]))])
# Epoch: 20 | Loss : 0.004575380124151707| test loss:0.004555904772132635
# OrderedDict([('weights', tensor([0.4952])), ('bias', tensor([0.2088]))])
# Epoch: 30 | Loss : 0.004575380124151707| test loss:0.004555904772132635
# OrderedDict([('weights', tensor([0.4952])), ('bias', tensor([0.2088]))])
# Epoch: 40 | Loss : 0.004575380124151707| test loss:0.004555904772132635
# OrderedDict([('weights', tensor([0.4952])), ('bias', tensor([0.2088]))])

# %%
with torch.inference_mode():
    y_preds_new=model_0(X_test)
plot_pred(predictions=y_preds_new)
# Out:
# C:\Users\Darsh\AppData\Local\Temp\ipykernel_24896\2038289084.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(prop={"size": 14});

# %%
weight,bias
# Out:
# (0.5, 0.2)
