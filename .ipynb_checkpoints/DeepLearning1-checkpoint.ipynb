# %%
import torch 
from torch import nn
import matplotlib.pyplot as plt
torch.__version__
# Out:
# '2.10.0+cpu'

# %%
weight=0.5
bias=0.2
start=0
end=1
step=0.02
X=torch.arange(start,end,step).unsqueeze(dim=1)
y=weight*X +bias
train_split=int(0.8*len(X))
# train_split
X
# Out:
# tensor([[0.0000],
#         [0.0200],
#         [0.0400],
#         [0.0600],
#         [0.0800],
#         [0.1000],
#         [0.1200],
#         [0.1400],
#         [0.1600],
#         [0.1800],
#         [0.2000],
#         [0.2200],
#         [0.2400],
#         [0.2600],
#         [0.2800],
#         [0.3000],
#         [0.3200],
#         [0.3400],
#         [0.3600],
#         [0.3800],
#         [0.4000],
#         [0.4200],
#         [0.4400],
#         [0.4600],
#         [0.4800],
#         [0.5000],
#         [0.5200],
#         [0.5400],
#         [0.5600],
#         [0.5800],
#         [0.6000],
#         [0.6200],
#         [0.6400],
#         [0.6600],
#         [0.6800],
#         [0.7000],
#         [0.7200],
#         [0.7400],
#         [0.7600],
#         [0.7800],
#         [0.8000],
#         [0.8200],
#         [0.8400],
#         [0.8600],
#         [0.8800],
#         [0.9000],
#         [0.9200],
#         [0.9400],
#         [0.9600],
#         [0.9800]])

# %%
X_train,y_train=X[:train_split],y[:train_split]
X_test,y_test=X[train_split:],y[train_split:]

# %%
len(X_train),len(y_train),len(y_test)
# Out:
# (40, 40, 10)

# %%
"""
Plotting a graph for visualization
"""
def plot_pred(train_data=X_train,
             train_label=y_train,
             test_data=X_test,
             test_label=y_test,
             predictions=None):
    plt.figure(figsize=(10,7))
    plt.scatter(train_data,train_label,c="b")
    plt.scatter(test_data,test_label,c="g")
    if predictions is not None:
        plt.scatter(test_data,predictions,c="r")
    plt.legend(prop={"size": 14});

# %%
plot_pred()
# Out:
# C:\Users\Darsh\AppData\Local\Temp\ipykernel_17376\2038289084.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(prop={"size": 14});

# %%
#Building basic linear regression model in pytorch 

class LinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.weights=nn.Parameter(torch.randn(1,requires_grad=True,dtype=torch.float32))
        self.bias=nn.Parameter(torch.randn(1,requires_grad=True,dtype=torch.float32))
    def forward(self,x:torch.tensor)->torch.Tensor:
        return self.weights*x+self.bias

# %%
torch.manual_seed(42) # with random seed we can ensure that every time random initiate of weight,size parameter stays constant
model_0=LinearRegressionModel()
list(model_0.parameters())
# Out:
# [Parameter containing:
#  tensor([0.3367], requires_grad=True),
#  Parameter containing:
#  tensor([0.1288], requires_grad=True)]

# %%
with torch.inference_mode():  #when we just wanna check prediction and we dont want gradient descent and back prop we use this
    y_preds=model_0(X_test)
y_preds
# Out:
# tensor([[0.3982],
#         [0.4049],
#         [0.4116],
#         [0.4184],
#         [0.4251],
#         [0.4318],
#         [0.4386],
#         [0.4453],
#         [0.4520],
#         [0.4588]])

# %%
plot_pred(predictions=y_preds)
# Out:
# C:\Users\Darsh\AppData\Local\Temp\ipykernel_17376\2038289084.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(prop={"size": 14});

# %%
loss_fn=nn.L1Loss()
#loss function measures loss between predicted and actuall value

# %%
loss_fn
# Out:
# L1Loss()

# %%
optimizer=torch.optim.SGD(params=model_0.parameters(),lr=0.01)
#optimizer try to modify parameters such as weight and bias to reduce the loss we hve SGD is stochastic gradient descent is
#optimizer/works like gradient descent it try to reduce the loss by balancing weight and 
#lr is how drastically we wanna change our parameters and its also comes under hyperperameter

# %%
torch.manual_seed(42)
epochs=25
epoch_count=[]
loss_count=[]
test_loss=[]
for epoch in range(epochs):
    model_0.train()

    y_pred=model_0(X_train)
    
    loss=loss_fn(y_pred,y_train)
    
    optimizer.zero_grad()

    loss.backward()
    print(f"loss before optimizer step{loss}")
    print(model_0.state_dict())
    optimizer.step() # it updates parameters and trys to move it forward or near to our answer 
    optimizer.step()

# recompute loss
    y_pred_new = model_0(X_train)
    new_loss = loss_fn(y_pred_new, y_train)
    print(f"loss after optimizer step {new_loss}")
    print(model_0.state_dict())
    with torch.no_grad():
        test_pred=model_0(X_test)
        test_loss=loss_fn(test_pred,y_test)
    if epoch%10==0:
        print(f"Epoch: {epoch} | Loss : {loss}| test loss:{test_loss}")
        print(model_0.state_dict())
# Out:
# loss before optimizer step0.13488134741783142
# OrderedDict([('weights', tensor([0.3367])), ('bias', tensor([0.1288]))])
# loss after optimizer step 0.11183933913707733
# OrderedDict([('weights', tensor([0.3445])), ('bias', tensor([0.1488]))])
# Epoch: 0 | Loss : 0.13488134741783142| test loss:0.18959416449069977
# OrderedDict([('weights', tensor([0.3445])), ('bias', tensor([0.1488]))])
# loss before optimizer step0.11183933913707733
# OrderedDict([('weights', tensor([0.3445])), ('bias', tensor([0.1488]))])
# loss after optimizer step 0.08879733830690384
# OrderedDict([('weights', tensor([0.3523])), ('bias', tensor([0.1688]))])
# loss before optimizer step0.08879733830690384
# OrderedDict([('weights', tensor([0.3523])), ('bias', tensor([0.1688]))])
# loss after optimizer step 0.06575533747673035
# OrderedDict([('weights', tensor([0.3601])), ('bias', tensor([0.1888]))])
# loss before optimizer step0.06575533747673035
# OrderedDict([('weights', tensor([0.3601])), ('bias', tensor([0.1888]))])
# loss after optimizer step 0.04368256777524948
# OrderedDict([('weights', tensor([0.3679])), ('bias', tensor([0.2088]))])
# loss before optimizer step0.04368256777524948
# OrderedDict([('weights', tensor([0.3679])), ('bias', tensor([0.2088]))])
# loss after optimizer step 0.030523519963026047
# OrderedDict([('weights', tensor([0.3756])), ('bias', tensor([0.2248]))])
# loss before optimizer step0.030523519963026047
# OrderedDict([('weights', tensor([0.3756])), ('bias', tensor([0.2248]))])
# loss after optimizer step 0.0247935988008976
# OrderedDict([('weights', tensor([0.3825])), ('bias', tensor([0.2348]))])
# loss before optimizer step0.0247935988008976
# OrderedDict([('weights', tensor([0.3825])), ('bias', tensor([0.2348]))])
# loss after optimizer step 0.022522693499922752
# OrderedDict([('weights', tensor([0.3882])), ('bias', tensor([0.2398]))])
# loss before optimizer step0.022522693499922752
# OrderedDict([('weights', tensor([0.3882])), ('bias', tensor([0.2398]))])
# loss after optimizer step 0.02141794003546238
# OrderedDict([('weights', tensor([0.3929])), ('bias', tensor([0.2418]))])
# loss before optimizer step0.02141794003546238
# OrderedDict([('weights', tensor([0.3929])), ('bias', tensor([0.2418]))])
# loss after optimizer step 0.020646613091230392
# OrderedDict([('weights', tensor([0.3969])), ('bias', tensor([0.2418]))])
# loss before optimizer step0.020646613091230392
# OrderedDict([('weights', tensor([0.3969])), ('bias', tensor([0.2418]))])
# loss after optimizer step 0.01994861662387848
# OrderedDict([('weights', tensor([0.4005])), ('bias', tensor([0.2408]))])
# loss before optimizer step0.01994861662387848
# OrderedDict([('weights', tensor([0.4005])), ('bias', tensor([0.2408]))])
# loss after optimizer step 0.019250622019171715
# OrderedDict([('weights', tensor([0.4041])), ('bias', tensor([0.2398]))])
# Epoch: 10 | Loss : 0.01994861662387848| test loss:0.04553236439824104
# OrderedDict([('weights', tensor([0.4041])), ('bias', tensor([0.2398]))])
# loss before optimizer step0.019250622019171715
# OrderedDict([('weights', tensor([0.4041])), ('bias', tensor([0.2398]))])
# loss after optimizer step 0.01855500601232052
# OrderedDict([('weights', tensor([0.4077])), ('bias', tensor([0.2388]))])
# loss before optimizer step0.01855500601232052
# OrderedDict([('weights', tensor([0.4077])), ('bias', tensor([0.2388]))])
# loss after optimizer step 0.017880210652947426
# OrderedDict([('weights', tensor([0.4109])), ('bias', tensor([0.2368]))])
# loss before optimizer step0.017880210652947426
# OrderedDict([('weights', tensor([0.4109])), ('bias', tensor([0.2368]))])
# loss after optimizer step 0.017182212322950363
# OrderedDict([('weights', tensor([0.4145])), ('bias', tensor([0.2358]))])
# loss before optimizer step0.017182212322950363
# OrderedDict([('weights', tensor([0.4145])), ('bias', tensor([0.2358]))])
# loss after optimizer step 0.01650458201766014
# OrderedDict([('weights', tensor([0.4181])), ('bias', tensor([0.2348]))])
# loss before optimizer step0.01650458201766014
# OrderedDict([('weights', tensor([0.4181])), ('bias', tensor([0.2348]))])
# loss after optimizer step 0.015811806544661522
# OrderedDict([('weights', tensor([0.4213])), ('bias', tensor([0.2328]))])
# loss before optimizer step0.015811806544661522
# OrderedDict([('weights', tensor([0.4213])), ('bias', tensor([0.2328]))])
# loss after optimizer step 0.015126561746001244
# OrderedDict([('weights', tensor([0.4249])), ('bias', tensor([0.2318]))])
# loss before optimizer step0.015126561746001244
# OrderedDict([('weights', tensor([0.4249])), ('bias', tensor([0.2318]))])
# loss after optimizer step 0.01444140262901783
# OrderedDict([('weights', tensor([0.4281])), ('bias', tensor([0.2298]))])
# loss before optimizer step0.01444140262901783
# OrderedDict([('weights', tensor([0.4281])), ('bias', tensor([0.2298]))])
# loss after optimizer step 0.013748535886406898
# OrderedDict([('weights', tensor([0.4317])), ('bias', tensor([0.2288]))])
# loss before optimizer step0.013748535886406898
# OrderedDict([('weights', tensor([0.4317])), ('bias', tensor([0.2288]))])
# loss after optimizer step 0.013070997782051563
# OrderedDict([('weights', tensor([0.4348])), ('bias', tensor([0.2268]))])
# loss before optimizer step0.013070997782051563
# OrderedDict([('weights', tensor([0.4348])), ('bias', tensor([0.2268]))])
# loss after optimizer step 0.012372998520731926
# OrderedDict([('weights', tensor([0.4384])), ('bias', tensor([0.2258]))])
# Epoch: 20 | Loss : 0.013070997782051563| test loss:0.028987396508455276
# OrderedDict([('weights', tensor([0.4384])), ('bias', tensor([0.2258]))])
# loss before optimizer step0.012372998520731926
# OrderedDict([('weights', tensor([0.4384])), ('bias', tensor([0.2258]))])
# loss after optimizer step 0.01169811375439167
# OrderedDict([('weights', tensor([0.4420])), ('bias', tensor([0.2248]))])
# loss before optimizer step0.01169811375439167
# OrderedDict([('weights', tensor([0.4420])), ('bias', tensor([0.2248]))])
# loss after optimizer step 0.01100259367376566
# OrderedDict([('weights', tensor([0.4452])), ('bias', tensor([0.2228]))])
# loss before optimizer step0.01100259367376566
# OrderedDict([('weights', tensor([0.4452])), ('bias', tensor([0.2228]))])
# loss after optimizer step 0.010320092551410198
# OrderedDict([('weights', tensor([0.4488])), ('bias', tensor([0.2218]))])
# loss before optimizer step0.010320092551410198
# OrderedDict([('weights', tensor([0.4488])), ('bias', tensor([0.2218]))])
# loss after optimizer step 0.009632188826799393
# OrderedDict([('weights', tensor([0.4520])), ('bias', tensor([0.2198]))])

# %%
with torch.inference_mode():
    y_preds_new=model_0(X_test)
plot_pred(predictions=y_preds_new)
# Out:
# C:\Users\Darsh\AppData\Local\Temp\ipykernel_17376\2038289084.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(prop={"size": 14});

# %%
weight,bias
# Out:
# (0.5, 0.2)
